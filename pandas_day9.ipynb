# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rj7shakya/python_ml/main/cleaned_imdb.csv")
df.head(n=10)
# reads first five data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-bf37890c4c54> in <module>
# ----> 1 df = pd.read_csv("https://raw.githubusercontent.com/rj7shakya/python_ml/main/cleaned_imdb.csv")
#       2 df.head(n=10)
#       3 # reads first five data
#
# NameError: name 'pd' is not defined

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'color', 'director_name', 'num_critic_for_reviews',
#        'duration', 'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster',
#        'plot_keywords', 'movie_imdb_link', 'num_user_for_reviews', 'language',
#        'country', 'content_rating', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'imdb_score', 'aspect_ratio',
#        'movie_facebook_likes'],
#       dtype='object')

# %%
df = df.drop(columns = ['Unnamed: 0']) #delete the column
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron              723.000000     178.0
# 1     Color     Gore Verbinski              302.000000     169.0
# 2     Color         Sam Mendes              602.000000     148.0
# 3     Color  Christopher Nolan              813.000000     164.0
# 4     Color     Andrew Stanton              462.000000     132.0
# ...     ...                ...                     ...       ...
# 4549  Color   Neill Dela Llana               35.000000      80.0
# 4550  Color   Robert Rodriguez               56.000000      81.0
# 4551  Color    Anthony Vallone              322.146105      84.0
# 4552  Color       Edward Burns               14.000000      95.0
# 4553  Color           Jon Gunn               43.000000      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# ...

# %%
df.head()

# %%
df.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4549  Color  Neill Dela Llana               35.000000      80.0
# 4550  Color  Robert Rodriguez               56.000000      81.0
# 4551  Color   Anthony Vallone              322.146105      84.0
# 4552  Color      Edward Burns               14.000000      95.0
# 4553  Color          Jon Gunn               43.000000      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4549                      0.0                     0.0     Edgar Tancangco
# 4550                      0.0                     6.0     Peter Marquardt
# 4551                      2.0                     2.0      John Considine
# 4552                      0.0                   133.0  Caitlin FitzGerald
# 4553                     16.0                    16.0    Brian Herzlinger
#
#       actor_1_facebook_likes         gross  \
# 4549                     0.0  7.007100e+04
# 4550                   121.0  2.040920e+06
# ...

# %%
df.loc[:]['director_name'] #read the
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4          Andrew Stanton
#               ...
# 4549     Neill Dela Llana
# 4550     Robert Rodriguez
# 4551      Anthony Vallone
# 4552         Edward Burns
# 4553             Jon Gunn
# Name: director_name, Length: 4554, dtype: object

# %%
df.loc[0:4][['movie_title','budget','imdb_score']]
# Out:
#                                  movie_title       budget  imdb_score
# 0                                    Avatar   237000000.0         7.9
# 1  Pirates of the Caribbean: At World's End   300000000.0         7.1
# 2                                   Spectre   245000000.0         6.8
# 3                     The Dark Knight Rises   250000000.0         8.5
# 4                               John Carter   263700000.0         6.6

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.loc[0:5][['movie_title','budget','imdb_score','movie_facebook_likes']]
# Out:
#                                  movie_title       budget  imdb_score  \
# 0                                    Avatar   237000000.0         7.9
# 1  Pirates of the Caribbean: At World's End   300000000.0         7.1
# 2                                   Spectre   245000000.0         6.8
# 3                     The Dark Knight Rises   250000000.0         8.5
# 4                               John Carter   263700000.0         6.6
# 5                              Spider-Man 3   258000000.0         6.2
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 4                 24000
# 5                     0

# %%
# 
df.iloc[:,4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d677367bee82> in <module>
#       1 #
# ----> 2 df.iloc[:,4]
#
# NameError: name 'df' is not defined

# %%
df.loc[1][:]
# Out:
# color                                                                    Color
# director_name                                                   Gore Verbinski
# num_critic_for_reviews                                                   302.0
# duration                                                                 169.0
# director_facebook_likes                                                  563.0
# actor_3_facebook_likes                                                  1000.0
# actor_2_name                                                     Orlando Bloom
# actor_1_facebook_likes                                                 40000.0
# gross                                                              309404152.0
# genres                                                Action|Adventure|Fantasy
# actor_1_name                                                       Johnny Depp
# movie_title                          Pirates of the Caribbean: At World's End
# ...

# %%
df.iloc[0,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6c25f0bdee0e> in <module>
# ----> 1 df.iloc[0,1]
#
# NameError: name 'df' is not defined

# %%
df.iloc[1:4,1]
# Out:
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# Name: director_name, dtype: object

# %%
df.iloc[1:4,5:7] # i points to index
# Out:
#    actor_3_facebook_likes    actor_2_name
# 1                  1000.0   Orlando Bloom
# 2                   161.0    Rory Kinnear
# 3                 23000.0  Christian Bale

# %%
index = df.columns.get_loc('director_name')
index
df.iloc[:,index]
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4          Andrew Stanton
#               ...
# 4549     Neill Dela Llana
# 4550     Robert Rodriguez
# 4551      Anthony Vallone
# 4552         Edward Burns
# 4553             Jon Gunn
# Name: director_name, Length: 4554, dtype: object

# %%
df.sort_values(by=['director_facebook_likes'],ascending=True).head()
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 823   Color           Frank Oz                   140.0      85.0
# 3041  Color        David Lynch                   143.0     112.0
# 826   Color    Robert Zemeckis                    49.0     104.0
# 3039  Color  Timothy Björklund                    33.0      74.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# 823                       0.0                   490.0    Adam Alexi-Malle
# 3041                      0.0                   201.0  Richard Farnsworth
# 826                       0.0                   812.0        Meryl Streep
# 3039                      0.0                   719.0      Kelsey Grammer
#
#       actor_1_facebook_likes        gross  \
# 0                     1000.0  760505847.0
# ...

# %%
df.sort_values(by=['budget'],ascending=False).loc[:6][['movie_title','budget']]
# Out:
#                                     movie_title        budget
# 2861                                  The Host   1.221550e+10
# 3645                            Lady Vengeance   4.200000e+09
# 2878                                  Fateless   2.500000e+09
# 2235                         Princess Mononoke   2.400000e+09
# 2246                                  Steamboy   2.127520e+09
# 3259                                     Akira   1.100000e+09
# 4209                             Godzilla 2000   1.000000e+09
# 2943                    Kabhi Alvida Naa Kehna   7.000000e+08
# 3143                            Trading Places   7.000000e+08
# 3637                                     Tango   7.000000e+08
# 4038                                  Stitches   6.758157e+08
# 1740   The Sisterhood of the Traveling Pants 2   5.863231e+08
# 4014                             Clockwatchers   5.702012e+08
# 1290                                 Red Cliff   5.536320e+08
# ...

# %%
df.sort_values(by=['imdb_score'],ascending=False).head().loc[:][['movie_title','budget']]
# Out:
#                     movie_title       budget
# 1864  The Shawshank Redemption    25000000.0
# 3293             The Godfather     6000000.0
# 2714    The Godfather: Part II    13000000.0
# 65             The Dark Knight   185000000.0
# 4416              12 Angry Men      350000.0

# %%
df.shape
# Out:
# (4554, 28)

# %%
df.dropna?

# %%
val = df.dropna()  # return data
val
# df.dropna(inplace=True)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron              723.000000     178.0
# 1     Color     Gore Verbinski              302.000000     169.0
# 2     Color         Sam Mendes              602.000000     148.0
# 3     Color  Christopher Nolan              813.000000     164.0
# 4     Color     Andrew Stanton              462.000000     132.0
# ...     ...                ...                     ...       ...
# 4549  Color   Neill Dela Llana               35.000000      80.0
# 4550  Color   Robert Rodriguez               56.000000      81.0
# 4551  Color    Anthony Vallone              322.146105      84.0
# 4552  Color       Edward Burns               14.000000      95.0
# 4553  Color           Jon Gunn               43.000000      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# ...

# %%
# grouping of data
df.groupby(['title_year'])['budget'].mean()
# Out:
# <ipython-input-49-b14cbb32d5d6>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['title_year'])['imdb_score','budget'].mean()
#             imdb_score        budget
# title_year
# 1916.0        8.000000  3.859070e+05
# 1925.0        8.300000  2.450000e+05
# 1927.0        8.300000  6.000000e+06
# 1929.0        7.150000  6.452747e+07
# 1930.0        7.800000  3.950000e+06
# ...                ...           ...
# 2012.0        6.303030  4.801066e+07
# 2013.0        6.413568  4.687214e+07
# 2014.0        6.300000  4.357012e+07
# 2015.0        6.133533  4.926142e+07
# 2016.0        6.336709  6.757634e+07
#
# [90 rows x 2 columns]

# %%
df.groupby(['title_year'])['budget'].max()
# Out:
# title_year
# 1916.0    3.859070e+05
# 1925.0    2.450000e+05
# 1927.0    6.000000e+06
# 1929.0    1.286759e+08
# 1930.0    3.950000e+06
#               ...
# 2012.0    6.758157e+08
# 2013.0    2.250000e+08
# 2014.0    3.065987e+08
# 2015.0    2.864922e+08
# 2016.0    2.500000e+08
# Name: budget, Length: 90, dtype: float64
