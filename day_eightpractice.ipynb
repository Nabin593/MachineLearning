# %%
import numpy as np
arr = np.array([1,2,3,4])
arr
type(arr)
# Out:
# numpy.ndarray

# %%
import datetime

A = datetime.datetime.now()
print(A)

x = abs(-6.87878)
x
# Out:
# 2022-12-31 13:41:04.647105
# 6.87878

# %%
import math

x = math.sqrt(64)

print(x)
# Out:
# 8.0

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
arr[1]
# Out:
# 2

# %%
arr[1] + arr[2]
# Out:
# 5

# %%
x = np.array([[2,3,8,7],[4,6,8,0]])
x
x[1,-2]
x.shape
# Out:
# (2, 4)

# %%
A = np.array([1,2,3,4,56,7,3,6,9])
A[1:5]
A[:6]
A[-3:-1]
# Out:
# array([3, 6])

# %%
import numpy as np
A = np.array([12,34,5,66,8,89,7,9,0])
print(A[-2:-3])
A.shape
# Out:
# []
# (9,)

# %%
D = np.array(['apple', 'banana', 'cherry'])
print(D.dtype)
# Out:
# <U6

# %%
F = np.array([2,3,4,5,6,7,8,9,90,0,7,65,4,3,2,1])
A = F.reshape(2,8)
new = F.reshape(4,1,4)
new
A
# Out:
# array([[ 2,  3,  4,  5,  6,  7,  8,  9],
#        [90,  0,  7, 65,  4,  3,  2,  1]])

# %%
arr1 = np.array([[1,2,3], [2,34,5]])
arr2 = np.array([[10,21,33], [32,4,4]])
arr = np.concatenate((arr1,arr2), axis=1)
arr
# Out:
# array([[ 1,  2,  3, 10, 21, 33],
#        [ 2, 34,  5, 32,  4,  4]])

# %%
import numpy as np

arr = np.array([1,2,3,7,8,9,6,5,4,3,3,1])
arr1 = np.array_split(arr, 7)
arr1
# Out:
# [array([1, 2]),
#  array([3, 7]),
#  array([8, 9]),
#  array([6, 5]),
#  array([4, 3]),
#  array([3]),
#  array([1])]
