# %%
a = 5
b = 2
c = a+b
print(c)
# Out:
# 7

# %%
x = 1
y = "nabin"
print(x)
type(x) 

print(y)
type(y)
# Out:
# 1
# nabin
# str

# %%
# variable example

x = "Nabin"
def myfunc():
  x = "harry"
  print('my name is:' + x)
myfunc()
print('my name is:' + x)
# Out:
# my name is:harry
# my name is:Nabin

# %%
a = int(2.8)
a
# Out:
# 2

# %%
# slicing of the string

b = "Hello Nepal"
b[2:9]
# Out:
# 'llo Nep'

# %%
a = "Hello , Nepal"
a.upper()
a.lower()
a.strip()
a.replace("H","w")
# Out:
# 'wello , Nepal'

# %%
x = ["ram","hari","krishina"]
x.append("shyam")
