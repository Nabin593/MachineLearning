# %%
class vehicle:
  def __init__(self,vehicleName,vehicleType):
    self.vehicleName=vehicleName
    self.vehicleType=vehicleType
  def getvehicleName(self):
    print(self.vehicleName)

xyzclass=vehicle("abc","mno")
xyzclass.getvehicleName()
# Out:
# abc

# %%
import numpy as np

data = np.array([[1,2,3],[3,4,5]])
data.reshape(3,2)
# shape should watch
# Out:
# array([[1, 2],
#        [3, 3],
#        [4, 5]])

# %%
import numpy as np

y_pred = np.array([2,4,6])
y_actual = np.array([1,3,5])

np.mean(np.square(np.subtract(y_pred,y_actual)))
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(10)
y1 = x**2
y2 = 2*x + 3
y3 = x**3 + 5

# plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.show()

# %%
plt.plot?

# %%
plt.scatter(x,y2,color='green',marker='*')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
x= np.arange(15)
y1 = x^3 + 3*x^2 + 3*x + 1
plt.plot(x,y1)
plt.scatter(x, y1, color='black', marker='*')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b10ff5e5d3cb> in <module>
#       1 x= np.arange(15)
#       2 y1 = x^3 + 3*x^2 + 3*x + 1
# ----> 3 plt.plot(x,y1)
#       4 plt.scatter(x, y1, color='black', marker='*')
#       5
#
# NameError: name 'plt' is not defined
